# %% [markdown]
# # Estimated checks until detection of a bad piece
#
# ## 98% good pieces
#
# If a process generates good pieces 98% of the time, how many consecutive good pieces can you expect to sample before you detect a bad piece?

# %%
sim2pct <- diff(which(rbinom(3000000, 1, 0.98) %in% 0))

# %%
den <- density(sim2pct)
plot(den)
# Out:
# Plot with title “density.default(x = sim2pct)”

# %%
print("Median")
print(median(sim2pct))
# Out:
# [1] "Median"
# [1] 35

# %%
print("Mean")
print(mean(sim2pct))
# Out:
# [1] "Mean"
# [1] 49.74878

# %%
print("Mode")
modeTable <- table(sim2pct)
print(names(modeTable[modeTable==max(modeTable)]))
# Out:
# [1] "Mode"
# [1] "2"

# %%
print("Density peak")
print(which.max(den$y))
# Out:
# [1] "Density peak"
# [1] 18

# %% [markdown]
# ## 99.5% good pieces
#
# If a process generates good pieces 99.5% of the time, how many consecutive good pieces can you expect to sample before you detect a bad piece?

# %%
sim0.5pct <- diff(which(rbinom(3000000, 1, 0.995) %in% 0))

# %%
den <- density(sim0.5pct)
plot(den)
# Out:
# Plot with title “density.default(x = sim0.5pct)”

# %%
print("Median")
median(sim0.5pct)
# Out:
# [1] "Median"
# [1] 138

# %%
print("Mean")
mean(sim0.5pct)
# Out:
# [1] "Mean"
# [1] 196.7701

# %%
print("Mode")
modeTable <- table(sim0.5pct)
print(names(modeTable[modeTable==max(modeTable)]))
# Out:
# [1] "Mode"
# [1] "3"

# %%
print("Density peak")
print(which.max(den$y))
# Out:
# [1] "Density peak"
# [1] 22
